# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
# 1.Problemin Çözümünü Buraya Yazınız
telefon_defteri = {"Ahmet" : "0532 678 13 19","Mehmet": "0543 543 42 42", "Kardelen" : "0533 533 33 33"}
isim = input("Telefon numarasını öğrenmek için bir kişi adı girin: ")
print (f"{isim} adlı kişinin telefon numarası: {telefon_defteri[isim]}")
# Out:
# Ahmet adlı kişinin telefon numarası: 0532 678 13 19

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
# 2.Problemin Çözümünü Buraya Yazınız
calısan = {"Ahmet":["Memleket:Adana, Yaş:40, Görev:Direktör"],"Mehmet":["Memleket:İstanbul, Yaş:35, Görev:Öğretmen"]}
isim = input("Lütfen bilgilerini görüntelemek istediğiniz çalışanın ismini girin:")
print(isim,calısan[isim][0], sep=" = ")
# Out:
# Ahmet = Memleket:Adana, Yaş:40, Görev:Direktör

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
# 3.Problemin Çözümünü Buraya Yazınız
ogrenciler = {"Ahmet": [72, 66, 48], "Enes":[88,96,100],"Berkcan":[70,50,40],"Begüm":[92,33,78],"Mertcan":[92,98,55]}
ogrenci = input("Lütfen notlarını görmek istediğiniz öğrencinin adını giriniz:")
ortalama = (ogrenciler[ogrenci][0] + ogrenciler[ogrenci][1] + ogrenciler[ogrenci][2])/3
print(ogrenci + "isimli öğrencinin 1. Sınav Notu:" + str(ogrenciler[ogrenci][0]) + "2. Sınav Notu:" + str(ogrenciler[ogrenci][1]) + "3. Sınav Notu:" + str(ogrenciler[ogrenci][2]) + "Ortalama:" + str(ortalama))
# Out:
# Ahmetisimli öğrencinin 1. Sınav Notu:722. Sınav Notu:663. Sınav Notu:48Ortalama:62.0

# %% [markdown]
# # Problem 4

# %%
# 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.
liste = ["Bmw", "Mercedes", "Opel", "Mazda"]
print(liste)
# 2-  Liste Kaç elemanlıdır ?
print(len(liste))

# 3-  Listenin ilk ve son elemanı nedir ?
print(liste[0] ,liste[3])

# 4-  Mazda değerini Toyota ile değiştirin.
deger = input("Lütfen değiştirmek istediğiniz değeri girin:")
deger_index = liste.index(deger)
yeni_deger = input("Lütfen yeni değeri girin:")
liste[deger_index] = yeni_deger
print(liste)

# 5-  Listenin -2 indeksindeki değer nedir ?
print(liste[-2])

# 6-  Listenin ilk 3 elemanını alın.
print(liste[:3])

# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.
liste = ["Bmw", "Mercedes", "Opel", "Mazda"]
deger1 = input("Lütfen değiştirmek istedğiniz ilk değeri giriniz:")
deger2 = input("Lütfen değiştirmek istediğiniz ikinci değeri giriniz:")
deger1_index = liste.index(deger1)
deger2_index = liste.index(deger2)
yeni_deger1 = input("Lütfen birinci yeni değeri giriniz:")
yeni_deger2 = input("Lütfen ikinci yeni değeri giriniz:")
liste[deger1_index] = yeni_deger1
liste[deger2_index] = yeni_deger2
print(liste)


# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.
liste = ["Bmw", "Mercedes", "Opel", "Mazda"]
deger1 = input("Lütfen eklemek istediğiniz ilk değeri giriniz:")
deger2 = input("Lütfen eklemek istediğiniz ikinci değeri giriniz:")
deger1_ek = liste.append(deger1)
deger2_ek = liste.append(deger2)
print(liste)

# 9- Listenin son elemanını silin.
liste = ["Bmw", "Mercedes", "Opel", "Mazda"]
liste.pop()
print(liste)

# 10- Liste elemanlarını tersten yazdırınız.
liste = ["Bmw", "Mercedes", "Opel", "Mazda"]
liste.reverse()
print(liste)

# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 
studentA = ["Yiğit Bilgi",2010,(70,60,70)]
studentB = ["Sena Turan", 1999, (80,80,70)]
studentC = ["Ahmet Turan", 1998, (80,70,90)]
print(studentA)
print(studentB)
print(studentC)

# 12- Liste elemanlarını ekrana yazdırınız.  
names = ['Ali','Yağmur','Hakan','Deniz']
for i in names:
      print(i)
years = [1998, 2000, 1998, 1987]
for i in years:
      print(i)

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.
names = ['Ali','Yağmur','Hakan','Deniz']
names.append("Cenk")
print(names)

# 14-  "Sena" değerini listenin başına ekleyiniz.
names = ['Ali','Yağmur','Hakan','Deniz']
names.insert(0,"Sena")
print(names)

# 15-  "Deniz" ismini listeden siliniz.
names = ['Ali','Yağmur','Hakan','Deniz']
del names[3]
print(names)

# 16-  "Ali" listenin bir elemanı mıdır ?
names = ['Ali','Yağmur','Hakan','Deniz']
n = input("Bir isim giriniz:")
if n in names:
      print(f"{n} listenin bir elemanıdır.")
else:
      print(f"{n} listenin bir elemanı değildir.")

# 17-  Liste elemanlarını ters çevirin.
names = ['Ali','Yağmur','Hakan','Deniz']
names.reverse()
print(names)

years = [1998, 2000, 1998, 1987]
years.reverse()
print(years)

# 18-  Liste elemanlarını alfabetik olarak sıralayınız.
names = ['Ali','Yağmur','Hakan','Deniz']
names.sort()
print(names)

# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.
years = [1998, 2000, 1998, 1987]
years.sort()
print(years)

# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.
str = "Chevrolet,Dacia"
print(list((str)))

# 21- years dizisinde kaç tane 1998 değeri vardır ?
years = [1998, 2000, 1998, 1987]
print(years.count(1998))

# 22- years dizisinin tüm elemanlarını siliniz.
years = [1998, 2000, 1998, 1987]
years.clear()
print(years)

# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
marka1 = input("Lütfen bir marka adı giriniz:")
marka2 = input("Lütfen bir marka adı giriniz:")
marka3 = input("Lütfen bir marka adı giriniz:")
liste1 = list((marka1))
liste2 = list((marka2))
liste3 = list((marka3))
yeni_liste = liste1 + liste2 + liste3
print(yeni_liste)
# Out:
# ['Bmw', 'Mercedes', 'Opel', 'Mazda']
# 4
# Bmw Mazda
# ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# Opel
# ['Bmw', 'Mercedes', 'Opel']
# ['Bmw', 'Mercedes', 'Toyota', 'Renault']
# ['Bmw', 'Mercedes', 'Opel', 'Mazda', 'Audi', 'Nissan']
# ['Bmw', 'Mercedes', 'Opel']
# ['Mazda', 'Opel', 'Mercedes', 'Bmw']
# ['Yiğit Bilgi', 2010, (70, 60, 70)]
# ['Sena Turan', 1999, (80, 80, 70)]
# ['Ahmet Turan', 1998, (80, 70, 90)]
# Ali
# Yağmur
# Hakan
# Deniz
# 1998
# 2000
# 1998
# 1987
# ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz']
# ['Ali', 'Yağmur', 'Hakan']
# Ali listenin bir elemanıdır.
# ['Deniz', 'Hakan', 'Yağmur', 'Ali']
# [1987, 1998, 2000, 1998]
# ['Ali', 'Deniz', 'Hakan', 'Yağmur']
# [1987, 1998, 1998, 2000]
# ['C', 'h', 'e', 'v', 'r', 'o', 'l', 'e', 't', ',', 'D', 'a', 'c', 'i', 'a']
# 2
# []
# ['M', 'a', 'v', 'i', 'Z', 'a', 'r', 'a', 'L', 'C', 'W']
